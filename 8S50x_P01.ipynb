# %% [markdown]
# <!--start-block-->
# <hr style="height: 1px;">
# <i>This notebook was authored by the 8.S50x Course Team, Copyright 2022 MIT All Rights Reserved.</i>
# <hr style="height: 1px;">
# <br>
#
# <h1>Guided Problem Set 1: Poisson Statistics and Probability</h1>
#
# <br>

# %% [markdown]
# <!--start-block MIT color #A31F34-->
# <a name='section_1_0'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">P1.0 Overview</h2>

# %% [markdown]
# <h3>Navigation</h3>
#
# <table style="width:100%">
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_1_1">P1.1 Random Variables and Probability Density Functions</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_1_1">P1.1 Problems</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_1_2">P1.2 Gaussian Distribution</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_1_2">P1.2 Problems</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_1_3">P1.3 Joint Probability Density Functions</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_1_3">P1.3 Problems</a></td>
#    </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_1_4">P1.4 Poisson Distribution</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_1_4">P1.4 Problems</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_1_5">P1.5 Simulating a Poisson Process</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_1_5">P1.5 Problems</a></td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_1_6">P1.6 Exponential Distribution (Optional)</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_1_6">P1.6 Problems</a></td>
#     </tr>
# </table>

# %% [markdown]
# <h3>Learning Objectives</h3>
#
# This problem set is aimed at building intuition for the understanding of random variables, and for the application of statistical tools in understanding physics datasets. We will focus on the tools used within the lectures, but here we will expand on them with longer problems that illustrate what's going on.
#
#
# In this problem set we will explore the following topics:
#
# - Introduction to random variables and their distributions
# - Introduction to the properties of a Gaussian distribution
# - Introduction to joint probability distributions of more than one variable
# - Introduction to the properties of a Poisson distribution
# - Examples of how a Poisson distribution arises in simulated data
# - Discussion of why the time between events in a Poisson distribution gives an exponential distribution

# %% [markdown]
# <h3>Importing Libraries</h3>
#
# Before beginning, run the cell below to import the relevant libraries for this notebook.

# %%
#>>>RUN: P1.0-runcell01

import numpy as np                   #https://numpy.org/doc/stable/
import matplotlib.pyplot as plt      #https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html
import scipy.stats as stats          #https://docs.scipy.org/doc/scipy/reference/stats.html
from scipy.special import factorial  #https://docs.scipy.org/doc/scipy/reference/generated/scipy.special.factorial.html

# %% [markdown]
# <h3>Setting Default Figure Parameters</h3>
#
# The following code cell sets default values for figure parameters.

# %%
#>>>RUN: P1.0-runcell02

#set plot resolution
# %config InlineBackend.figure_format = 'retina'

#set default figure parameters
plt.rcParams['figure.figsize'] = (9,6)

medium_size = 12
large_size = 15

plt.rc('font', size=medium_size)          # default text sizes
plt.rc('xtick', labelsize=medium_size)    # xtick labels
plt.rc('ytick', labelsize=medium_size)    # ytick labels
plt.rc('legend', fontsize=medium_size)    # legend
plt.rc('axes', titlesize=large_size)      # axes title
plt.rc('axes', labelsize=large_size)      # x and y labels
plt.rc('figure', titlesize=large_size)    # figure title

# %% [markdown]
# <!--start-block-->
# <a name='section_1_1'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">P1.1 Random Variables and Probability Density Functions</h2>
#
# | [Top](#section_1_0) | [Problems](#exercises_1_1) | [Next Section](#section_1_2) |

# %% [markdown]
# <h3>Random Variables</h3>
#
# We will begin with the concept of random variables, which is essential to probability and statistics.
#
# <u>Definition:</u> A <b>random variable</b> is (for the purposes of this course) an observable whose outcome may differ between experiments.
#
# For example, if you're measuring the length of a cube in your experiment, the length you measure is a random variable. This is because your measured results conceivably might vary, depending on how you take the measurement, the precision of the ruler, or even thermal expansion and contraction of the cube.
#
# If you're measuring the number of snakes in a population, the number of snakes you count is also a random variable.
#
# There are two types of random variables, continuous and discrete. Discrete random variables can only take on specific values (for example, counting something as in the snake example), whereas continuous random variables can take on an unenumerated range of values (for example, measuring a physical quantity as in the cube example).
#
# <u>Technical Note:</u> A random variable represents the whole range of possible values that the measurement could produce. The actual measured results are not random variables; they are data points. In this course, we will often represent random variables by capital letters and their measured values as lowercase letters.
# <br>
# <!--end-block-->

# %% [markdown]
# <!--start-block-->
#
# <h3>Probability Mass and Density Functions</h3>
#
# Discrete random variables are associated with a probability mass function that defines the exact probability that the random variable will take a certain discrete value. More precisely:
#
# <u>Definition:</u> The <b>probability mass function (PMF)</b> for a discrete random variable $R$ is a function $p(r)$ that gives the probability that the random variable $R$ will have the specific value $R=r$.</p>
#
# <u>Corollaries:</u>
#
# - The sum of $p(r)$ over all possible values of $R$ is exactly 1 (therefore, $p(r) \leq 1$ for all values of $r$)
# - $p(r)$ is unitless
# - $p(r)$ is nonnegative
#
#
# For continuous probability distributions, we have instead a probability *density* function.
#
# <u>Definition:</u> The <b>probability density function (PDF)</b> for a continuous random variable $R$ is a function $P(r)$ defined so that the probability of the random value $R$ being in the range between $a$ and $b$ is given by</p>
#
# $$
# \begin{equation}
# p(a < R < b) = \int_{a}^{b} P(r) dr
# \end{equation}
# $$
#
# <u>Corollaries:</u>
#
# - The integral of $P(r)$ over all possible values of $R$ is 1.
# - $P(r)$ has units of $1/r$
# - $P(r)$ is nonnegative
#
# Here, we are using the convention that lowercase $p$ represents a probability (either of a specific value or a range of values), and uppercase $P$ denotes a probability density.
#
# <br>
# <!--end-block-->

# %% [markdown]
# <a name='exercises_1_1'></a>
# | [Top](#section_1_0) | [Restart Section](#section_1_1) | [Next Section](#section_1_2) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Problem 1.1.1</span>
#
# Which of the following distributions represents a pdf? Choose from the two plot options.
#
# - The left plot (a) shows the probability of finding a certain number of spades when drawing 10 cards from a deck.
# - The right plot (b) shows the probability of finding a pond with a particular depth among a selection of ponds.
#
# After submitting your answer, you can look at the solution to see the code that generated these plots.
#
# <p align="center">
# <img alt="Examples of PDF or PMF (no particular order)" src="https://raw.githubusercontent.com/mitx-8s50/images/main/P01/fig1_v2.png" width="800"/>
# </p>

# %% [markdown]
# <!--start-block-->
# <a name='section_1_2'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">P1.2 Gaussian distribution</h2>
#
# | [Top](#section_1_1) | [Previous Section](#section_1_1) | [Problems](#exercises_1_2) | [Next Section](#section_1_3) |

# %% [markdown]
# <h3>Overview</h3>
#
# The most common probability distribution is the Gaussian or normal distribution, which represents many natural phenomena, especially in physics. The normal distribution for a random variable $x$ with mean  $\mu$ and standard deviation $\sigma$ is given by
#
# $$P(x) = \frac{1}{\sqrt{2\pi \sigma^2}} \exp\left(-\frac{1}{2}\frac{(x-\mu)^2}{\sigma^2}\right)$$
#
# In the problems below, use numpy to make some plots of the various Gaussian distributions.
#
# <br>

# %% [markdown]
# <a name='exercises_1_2'></a>
# | [Top](#section_1_0) | [Restart Section](#section_1_2) | [Next Section](#section_1_3) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Problem 1.2.1</span>
#
# Define a Gaussian function named `gauss_mu_sigma` (not using functions from scipy.stats), that takes 3 inputs: a single value or array of numbers `x`, the variable `mu`, and the variable `sigma`. Note that this function should work properly when `x` is a 1D numpy array. The function should be equal to:
#
# $$P(x) = \frac{1}{\sqrt{2\pi \sigma^2}} \exp\left(-\frac{1}{2}\frac{(x-\mu)^2}{\sigma^2}\right)$$
#
# You can use your function in the ungraded "follow-up" part of this problem.

# %%
#>>>PROBLEM: P1.2.1
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def gauss_mu_sigma(x,mu,sigma):
    return #your code here

#TEST
from scipy.stats import norm
mu = 1.
sigma = 2.
x=np.linspace(-1,1,10)
print(gauss_mu_sigma(x,mu,sigma))
print(norm.pdf(x,mu,sigma))

# %% [markdown]
# >#### Follow-up 1.2.1a (ungraded)
# >
# >Test your function by plotting two Gaussian distributions with the following parameters:
# >
# >1. $\mu=5, \sigma = 1.0$
# >2. $\mu=10, \sigma = 2.0$
# >
# >Try to write your own plotting function before viewing the solution code below. Keep in mind the rules of plotting etiquette discussed in Lesson 1.

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Problem 1.2.2</span>
#
# For a fixed value of $\mu$, what effect will increasing the standard deviation $\sigma$ have on the distribution?
#
# - Increasing sigma widens the distribution.
# - Increasing sigma narrows the distribution.
# - Increasing sigma does not affect the shape of the distribution.

# %% [markdown]
# >#### Follow-up 1.2.2a (ungraded)
# >
# >Try plotting various Gaussian distributions to understand how the function behaves. For instance, plot the following Gaussian distributions over the random variable $x$ for $x \in (-5,5)$. Feel free to try other values of $\mu$ and $\sigma$.
# >
# >1. $\mu=0, \sigma^2 = 0.2$
# >2. $\mu=0, \sigma^2 = 1.0$
# >3. $\mu=0, \sigma^2 = 5.0$
# >4. $\mu=-2, \sigma^2 = 0.5$
# >
# >Try this on your own before viewing the solution code below.

# %% [markdown]
# ><question multiplechoice>
#
# #PROBLEM NAME AND SETTINGS
# #-------------------------------------------------------
# csq_name='P01_02_02_followup_a'
# csq_npoints = 0
#
#
# #PROMPT
# #-------------------------------------------------------
# csq_prompt ="""#### <span style="color: #000000;">Follow-up 1.2.2a (ungraded)</span>
#
# <span style="color: #000000;">Try plotting various Gaussian distributions to understand how the function behaves. For instance, plot the following Gaussian distributions over the random variable $x$ for $x \in (-5,5)$. Feel free to try other values of $\mu$ and $\sigma$.</span>
#
# <span style="color: #000000;">1. $\mu=0, \sigma^2 = 0.2$</span>
#
# <span style="color: #000000;">2. $\mu=0, \sigma^2 = 1.0$</span>
#
# <span style="color: #000000;">3. $\mu=0, \sigma^2 = 5.0$</span>
#
# <span style="color: #000000;">4. $\mu=-2, \sigma^2 = 0.5$</span>
#
# <span style="color: #000000;">Try this on your own before viewing the solution code below.</span>
#
# ADD_FOLLOWUP_PROMPT
#
#
# #EXPLANATION
# #-------------------------------------------------------
# csq_explanation = r"""See solution code below:
#
# <pre>
# #>>>RUN
# # Run this cell as follow-up to the previous exercise.
#
# x = np.linspace(-5,5, 1000) #make a vector of points from -5 to 5 with 1000 data points
#
#
# plot_gauss_pdf(x,0.,np.sqrt(0.2))
# plot_gauss_pdf(x,0.,np.sqrt(1.))
# plot_gauss_pdf(x,0.,np.sqrt(5.0))
# plot_gauss_pdf(x,-2.,np.sqrt(0.5))
# plt.grid()
# plt.show()
# </pre>"""
# </question>

# %% [markdown]
# <br>
# <!--start-block-->
#
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Problem 1.2.3</span>
#
# Write a function to sample 1000 data points from a Gaussian distribution with $\mu$ and $\sigma$, and return arrays containing the sampled values and bin centers for plotting a histogram. Specifically, the bins should be **centered** over the range 0-10 (inclusive) with bin-width 0.5.
#
# As a follow-up, plot both the histogram and the Gaussian function on the same plot.

# %%
#>>>PROBLEM: P1.2.3
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def get_gauss_data_bins(mu, sigma, num_samples):
    s_vals = #your code here, use np.random.normal
    bin_width = #your code here
    bin_num = #your code here
    bin_vals = #your code here
    return s_vals, bin_vals

# %% [markdown]
# >#### Follow-up 1.2.3a (ungraded)
# >
# >Plot both the histogram of sampled data and the Gaussian function on the same plot. What happens if you increase the number of points that are drawn? Try this on your own before viewing the solution code below.

# %% [markdown]
# <!--start-block-->
# <a name='section_1_3'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">P1.3 Joint Probability Density Functions</h2>
#
# | [Top](#section_1_0) | [Previous Section](#section_1_2) | [Problems](#exercises_1_3) | [Next Section](#section_1_4) |

# %% [markdown]
# <h3>Overview</h3>
#
# We can define joint probability density functions, e.g. $P(x,y)$, for multivariate probability distributions in a similar way as for single variables.
#
# <u>Definition:</u> The <b>joint PDF</b> for two continuous random variables $X$ and $Y$ is a function $P(x, y)$ defined so that the probability of the random values $X$ and $Y$ being in a particular region $RG$ in $x-y$ space is given by</p>
#
# $$p((X, Y)\in RG) = \iint_{RG} P(x, y) dx dy$$
#
# Note that we don't explicitly define ranges for the $x$ and $y$ integrals because there is no requirement in this definition that $RG$ be a rectangle in $x-y$ space.
#
# We define the single variable PDFs $P(x)$ and $P(y)$ by integrating (also called marginalizing) the extra variable from the joint PDF, i.e.,
#
# $$P(x) = \int_{-\infty}^{\infty} P(x,y) dy$$ and $$P(y) = \int_{-\infty}^{\infty} P(x,y) dx$$
#
#
# (Here, we implicitly assume that the possible values of $X$ and $Y$ are the whole real number line.)
#
# Now, we can introduce another very useful term in statistics: independence. Conceptually, two random variables are independent if measuring one tells you nothing about the possible values you will get when measuring the other. Mathematically, this means:
#
#
# <u>Definition:</u> Two random variables $X$ and $Y$ are <b>independent</b> from one another if the joint PDF factors into the product of the two single-variable PDFs:</i>
#
# $$P(x, y) = P(x) P(y).$$

# %% [markdown]
# <!--start-block-->
#
# Given $k$ independent Gaussian random variables, the above definition of independence guarantees that the joint PDF is
#
# $$
# \begin{eqnarray}
# P(x_1, x_2, ... x_k) &=& \prod_{i=1}^k P(x_i) \\
# & =& \frac{1}{ (2\pi)^{k/2}\prod_{i=1}^k \sigma_i} \exp \left(-\frac{1}{2}\sum_i \frac{(x_i- \mu_i)^2}{\sigma_i^2}\right)
# \end{eqnarray}
# $$
#
# where you note that the product of the $k$ exponential factors can be rewritten as a single exponential with its exponent being the sum of the exponential factors.
#
#
# In the problems below, let's visualize a multivariate Gaussian of two random variables.
#
# <br>
# <!--end-block-->

# %% [markdown]
# <a name='exercises_1_3'></a>
#
# | [Top](#section_1_0) | [Restart Section](#section_1_3) | [Next Section](#section_1_4) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Problem 1.3.1</span>
#
# Define a multivariate Gaussian distribution function named `mult_gauss_mu_sigma` that takes 6 inputs: a single value or array of numbers `x`, variables `mux` and `sigmax`; a single value or array of numbers `y`, and variables `muy` and `sigmay`. The functions for $x$ and $y$ should have the form:
#
# $$P(x_1, x_2, ... x_k) = \prod_{i=1}^k P(x_i) = \frac{1}{ (2\pi)^{k/2}\prod_i \sigma_i} \exp \left(-\frac{1}{2}\sum_i \frac{(x_i- \mu_i)^2}{\sigma_i^2}\right)$$
#
# and the same for $y$. Your function should return the joint probability density function $P(x_1, x_2,\ldots x_k, y_1, y_2, \ldots y_k)$
#
# **DO NOT** use `scipy.stats` for this problem. You may use your previously defined function `gauss_mu_sigma` (if it does not use `scipy.stats`).
#
#
# You can use your function by running the cell in the "follow-up" part of this problem.

# %%
#>>>PROBLEM: P1.3.1
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def mult_gauss_mu_sigma(x,y,mux,sigmax,muy,sigmay):
    return #your code here

# %% [markdown]
# >#### Follow-up 1.3.1a (ungraded)
# >
# >Consider the special case where: $\mu_x=\mu_y=0$ and $\sigma^2_x=\sigma^2_y=1$. Using matplotlib and numpy, plot the PDF that you defined above over the region $x \in [-5,5], y\in[-5,5]$.
# >
# >What happens when the values of the means and/or standard deviations are not equal? Try this on your own before looking at the solution code below.

# %% [markdown]
# <br>
# <!--start-block-->
#
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Problem 1.3.2</span>
#
# Consider how changing the mean and variance of one distribution would affect the overall distribution of the multivariate function. Try plotting the distribution with different values of $\mu_x$ , $\mu_y$, $\sigma_x$, and $\sigma_y$, as suggested in the follow-up to the previous question.
#
# Specifically, for the case when $\mu_x=\mu_y=0$ and $\sigma^2_x \neq \sigma^2_y$, you will obtain a plot like the one below:
#
# <p align="center">
# <img alt="multivariate function map" src="https://raw.githubusercontent.com/mitx-8s50/images/main/P01/image1.png" width="400"/>
# </p>
#
#
# In the case above, is it possible to rotate this ellipse by some angle in the $xy$-plane (i.e., the axes would no longer be parallel to the $x$ and $y$ axes) by changing one or more of the parameters of the function (without changing the functional form)? Why or why not?
#
#
# - Yes, it is possible.
# - No, it is not possible.

# %% [markdown]
# <!--start-block-->
# <a name='section_1_4'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">P1.4 Poisson Distributions</h2>
#
# | [Top](#section_1_0) | [Previous Section](#section_1_3) | [Problems](#exercises_1_4) | [Next Section](#section_1_5) |

# %% [markdown]
# <h3>Overview</h3>
#
# Another very common distribution in physics is the Poisson distribution.
#
# <u>Definition:</u> For a sequence of events that are independent of each other and independent of time, a random variable representing the number of events occurring within a given time interval obeys the <b>Poisson distribution</b>.</p>
#
# Examples include
# - the number of radioactive decays within a material over one second
# - the number of photons detected from a distant star in one day
# - the number of meteorite impacts on Earth in one year
#
# Note that the "interval" does not need to be a period of time. For example, if you want to study a probability distribution function of any measurement by counting how many events in a given data sample fall into a region (for example, $a \lt x \lt b$), that number of events will also be a Poisson distribution.
#
# Note that Poisson-distributed random variables are discrete.
#
# The PMF of a Poisson-distributed random variable with unitless parameter $\lambda$ is
#
# $$p(k)=\frac{\lambda^k e^{-\lambda}}{k!}.$$
#
# The parameter $\lambda$ is the average rate of events times the time interval over which $k$ events are detected:
#
# $$\lambda = \mathrm{(events\,per\, unit\, time)}\times\mathrm{(time\,interval)}$$
#
#
# The variable $k$ is the number of events in the time period.
#
# Alternatively, for counting events within an interval in a variable other than time, simply replace the word "time" in the discussion above by "length" or whatever quantity defines the interval in question.
#
# <br>
#
#
# A Poisson distribution approaches a Gaussian distribution for large values of $\lambda$.
#
# <br>

# %% [markdown]
# <h3>Example</h3>
#
# Run the following cell to see several examples of Poisson distributions with different values of $\lambda$. Each histogram is generated from 1500 samples of a Poisson distribution. A continuous Gaussian distribution and Gaussian mean are also plotted in each figure.
#
# Change the values of $\lambda$ (called "l" in the code below) in the list to see what effect that has, particularly as the values get larger.

# %%
#>>>RUN: P1.4-runcell01

def plot_many_Poisson(l,isamples):
    hists = {} # Dictionary that will contain the Poisson-distributed data, listed by l value

    #plotting-------------------
    fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(8,30))
    for k in range(len(ax)):
        #plot data
        np.random.seed(1)
        s = np.random.poisson(l[k],isamples)
        hists[l[k]]=s
        bins = np.arange(0, np.max(s) + 1, 1) - 0.5
        ax[k].hist(s, bins=bins, density=True, label="Poisson data")
        x = np.linspace(min(s),max(s),100)
        ax[k].plot(x,(1/(np.sqrt(2*np.pi*l[k])))*np.exp(-0.5*(x-l[k])**2.0/l[k]), label="Gaussian dist.")
        ax[k].axvline(x=l[k],c='r', label="Gaussian mean")
        
        #plot2 labels and style
        ax[k].legend(loc="upper right", fontsize=12)
        ax[k].set_xlabel("Counts in interval",fontsize=15)
        ax[k].set_ylabel("Probability of observation",fontsize=15)
        ax[k].set_title(f"lambda={l[k]}", fontsize=15)
        
        plt.setp(ax[k].get_xticklabels(), fontsize=12)
        plt.setp(ax[k].get_yticklabels(), fontsize=12)
        
        # plot grid
        ax[k].grid(alpha=0.2)
    
    return hists


        
# l is a list of lambda values
l = [1,5,10,25] 
samples = 1500
hists = plot_many_Poisson(l,samples)

plt.show()

# %% [markdown]
# <br>
#
# <a name='exercises_1_4'></a>
#
# | [Top](#section_1_0) | [Restart Section](#section_1_4) | [Next Section](#section_1_5) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Problem 1.4.1</span>
#
# Compute the mean and variance of the Poisson data (the output `hists`) generated by the  function shown above for $\lambda=25$. You can use the numpy functions for mean, `np.mean()`, and variance, `np.var()`. Enter your answer as a list of two numbers, `[mean, var]`, with precision 1e-3.

# %%
#>>>PROBLEM: P1.4.1

h = hists[25]
h_mean = #YOUR CODE HERE
h_var = #YOUR CODE HERE
    
print("Mean:",h_mean)
print("Variance:",h_var)

# %% [markdown]
# <br>
# <!--start-block-->
#
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Problem 1.4.2</span>
#
# Edit the code above to calculate the mean and variance of the Poisson distribution for values of $\lambda=1,5,10$. Try obtaining more samples from the distributions. What is the connection between $\lambda$, the data mean, and the data variance, in the limit of large samples?
#
# - The mean is always less than the variance.
# - The mean is always greater than the variance.
# - The mean and variance are equal.

# %% [markdown]
# <!--start-block-->
# <a name='section_1_5'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">P1.5 Simulating a Poisson Process</h2>
#
# | [Top](#section_1_0) | [Previous Section](#section_1_4) | [Problems](#exercises_1_5) | [Next Section](#section_1_6) |

# %% [markdown]
# <h3>Characteristics of Poisson Processes</h3>
#
# Let's simulate a **Poisson process**, which is just a process leading to a set of events that have the following characteristics:
#
# - they are independent of time, meaning that they are not more or less frequent depending on the time of detection
# - they are independent of each other, meaning the probability distribution of one event is unaffected by the presence of other events.
# - they do not occur at the same time.*
#
# A random variable that counts these events occurring within an interval is Poisson-distributed.
#
#
# *Note: Depending on the precision of your time measurement, two events could feasibly be detected together. But we assume that they are not created at the same time.
# <br>

# %% [markdown]
# <h3>Choosing Random Event Times</h3>
#
# Let's make a list of random event times from a uniform distribution. Convince yourself that these events are truly independent, since their distribution (the uniform random distribution) is the only distribution that depends neither on time nor the presence of other events.
#
# <br>

# %%
#>>>RUN: P1.5-runcell01

def random_event_data(NUM_EVENTS, TIME_RANGE):
    np.random.seed(1)
    event_times = np.random.random(NUM_EVENTS) * TIME_RANGE
    return event_times
    
    
def plot_random_times():
    event_times = random_event_data(NUM_EVENTS, TIME_RANGE)
    event_times.sort()

    #plotting-------------------
    #plot1 data
    plt.plot(event_times)
    
    #plot1 labels and style
    plt.title('', fontsize = 15)
    plt.xlabel("Event number", fontsize = 15)
    plt.ylabel("Time of occurrence", fontsize = 15)

    # changing the fontsize of ticks
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    
    plt.grid()
    plt.show()
    
    
    
NUM_EVENTS = 500
TIME_RANGE = 250

print("Average event rate:", NUM_EVENTS / TIME_RANGE, "events per second")
plot_random_times()

# %% [markdown]
# <br>
# <!--start-block-->
#
# <h3>Counting Events</h3>
#
# Let's count the number of events occurring in every interval of 1 second and display it in a histogram.

# %%
#>>>RUN: P1.5-runcell02

def func_(NUM_EVENTS, TIME_RANGE, TIME_INTERVAL):
    #the double back-slash makes num_intervals an integer
    num_intervals = TIME_RANGE // TIME_INTERVAL
    
    #get event times
    event_times = random_event_data(NUM_EVENTS, TIME_RANGE)
    
    #the number of events that occur between i and i+1 seconds
    counts = [np.sum(
            (event_times > i * TIME_INTERVAL) & (event_times < (i+1) * TIME_INTERVAL)
        ) for i in range(num_intervals)]
    #The long way to write the above
    #counts = np.array([])
    #for i in range(num_intervals):
    #    sumvals=0
    #    for event_time in event_times:
    #        if (event_time > i * TIME_INTERVAL) and (event_time < (i+1) * TIME_INTERVAL):
    #            sumvals=sumvals+1
    #    counts = np.append(counts,sumvals)

    
    bins = np.arange(np.max(counts)+2)-0.5 # Center the bins on the integers
        
    #plotting-------------------
    #plot data    
    #the histogram data can be normalized such that the area
    #under the curve=1 by setting density=true
    plt.hist(counts, bins=bins)#, density=True)

    #plot1 labels and style
    plt.title('', fontsize = 15)
    plt.xlabel("Number of events in an interval of length: " + str(TIME_INTERVAL) + "s", fontsize = 15)
    plt.ylabel("Number of intervals in data set", fontsize = 15)

    # changing the fontsize of ticks
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(alpha=0.5)
    #plt.show()
    
    
NUM_EVENTS = 500
TIME_RANGE = 250
TIME_INTERVAL = 1
func_(NUM_EVENTS, TIME_RANGE, TIME_INTERVAL)

# %% [markdown]
# <br>
#
# <a name='exercises_1_5'></a>
#
# | [Top](#section_1_0) | [Restart Section](#section_1_5) | [Next Section](#section_1_6) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Problem 1.5.1</span>
#
# Let's add the Poisson PMF to the histogram above. Specifically, the function:
#
# $$p(k)=\frac{\lambda^k e^{-\lambda}}{k!}.$$
#
# First, consider the same Poisson process where 500 events occur within a time range of 250 seconds (thus, the average time between events is known). What is the value of $\lambda$ for a given time interval smaller than 250 seconds?
#
# Express your answer in terms of the variables $\Delta t$ for the time interval, $N$ for the total number of events over the entire time range, and $T$ for the total time range. Use `Deltat` for $\Delta t$ , `N` for $N$, and `T` for $T$.

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Problem 1.5.2</span>
#
# Now define a function `Poisson_PMF` that takes `TIME_INTERVAL`, `NUM_EVENTS`, `TIME_RANGE`, and `k` as inputs, and outputs the Poisson PMF as a function of `k` (the output of the function will be an array of length `k`).
#
# In other words, define a function that yeilds:
#
# $$p(k)=\frac{\lambda^k e^{-\lambda}}{k!}.$$
#
# You may choose to use `scipy.stats` in this case, if you wish.

# %%
#>>>PROBLEM: P1.5.2
from scipy.special import factorial

def Poisson_PMF(NUM_EVENTS, TIME_RANGE, TIME_INTERVAL, k):
    return #your code here

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Problem 1.5.3</span>
#
# Finally, plot the function `Poisson_PMF` and compare with simulated data by computing the function over the range of the simulated data above, and then plotting the points on top of the simulated data.
#
# What do the distributions look like? Choose the best answer from the available options:
#
# - They match perfectly!
# - There is a systematic offset due to the computational method.
# - They line up closely, but are not exact due to the discrete nature of the data.

# %%
#>>>PROBLEM: P1.5.3

NUM_EVENTS = 500
TIME_RANGE = 250
TIME_INTERVAL = 1
func_(NUM_EVENTS, TIME_RANGE, TIME_INTERVAL)
kin=np.arange(0,10)
poisson=(TIME_RANGE/TIME_INTERVAL)*(Poisson_PMF(NUM_EVENTS, TIME_RANGE, TIME_INTERVAL,kin))
plt.plot(kin,poisson,'o')
plt.show()

# %% [markdown]
# >#### Follow-up 1.5.3a (ungraded)
# >
# >Try playing with the parameters (`NUM_EVENTS`, `TIME_RANGE`, and `TIME_INTERVAL`). Explore different interval lengths. Try large numbers of events per interval if you want a very good fit between the Poisson PMF and the data.

# %%
#>>>PROBLEM: P1.5.3a

def Poisson_data(NUM_EVENTS, TIME_RANGE, TIME_INTERVAL):
    np.random.seed(1)
    num_intervals = #your code here
    event_times = #your code here, draw a number of events from np.random.random, and multiply by the time range
    counts = #your code here, sum the number of events in each interval, returns a list of counts for each bin
    return counts

# %%
#>>>RUN: P1.5-runcell03

# Run this cell after completing the problem objective above.


def plot_1(NUM_EVENTS, TIME_RANGE, TIME_INTERVAL):
    counts = Poisson_data(NUM_EVENTS, TIME_RANGE, TIME_INTERVAL)
    bins = np.arange(np.max(counts)+2)-0.5 # Center the bins on the integers

    #plotting-------------------
    #plot data   
    #the histogram data are normalized such that the area
    #under the curve =1 by setting density=true
    hist_vals, bins, bars = plt.hist(counts, bins=bins, density=True)
    
    #print(sum(hist_vals[0:4]) + sum(hist_vals[4:]))
    
    k = np.arange(np.max(counts)+1, dtype=int)
    plt.plot(k,Poisson_PMF(NUM_EVENTS, TIME_RANGE, TIME_INTERVAL,k), label="Poisson PDF")
    
    #plot1 labels and style
    plt.title('', fontsize = 15)
    plt.xlabel("Number of events in an interval of length: " + str(TIME_INTERVAL) + "s", fontsize = 15)
    plt.ylabel("Fraction of intervals in data set", fontsize = 15)
    plt.legend(loc=1, fontsize = 12)
    
    # changing the fontsize of ticks
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
 
    return hist_vals


NUM_EVENTS = 500
TIME_RANGE = 250
TIME_INTERVAL = 1

#Trying something else
#NUM_EVENTS = 100*365 #rate is 100 events per day, we multiply by one year
#TIME_RANGE = 60*24*365 #60min/hr * 24 hrs/day * 365 days = observation time of 1 year
#TIME_INTERVAL = 60 #how many events do we expect to see in 1hr

hist_vals = plot_1(NUM_EVENTS, TIME_RANGE, TIME_INTERVAL)


print('Probability of <= 5 events:', sum(hist_vals[0:5]))

# %% [markdown]
# <!--start-block-->
# <a name='section_1_6'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">P1.6 Optional Exercise: Exponential distributions</h2>
#
# | [Top](#section_1_0) | [Previous Section](#section_1_5) | [Problems](#exercises_1_6) |

# %% [markdown]
# <h3>Overview</h3>
#
# For Poisson processes, we've seen that
#
# - The probability distribution of each event's time of occurrence is <b>uniform</b>
# - The probability distribution of the number of events occurring within an interval is <b>Poisson</b>
#
# However, we have not discussed the probability distribution of the time $\Delta t$ between events. It turns out to be exponential, with PDF
#
# $$P(\Delta t)= r e^{-r \Delta t}$$
#
# where $r$ is the average event rate.
#
# <br>
# <!--end-block-->

# %% [markdown]
# <h3>Example</h3>
#
# Let's demonstrate this from our previous data.

# %%
#>>>RUN: P1.6-runcell01

def plot_new(NUM_EVENTS,TIME_RANGE):
    event_times = random_event_data(NUM_EVENTS, TIME_RANGE)
    event_times.sort()

    bins = np.linspace(0, 1, 10)
    deltas = [event_times[i+1] - event_times[i] for i in range(NUM_EVENTS - 1)]
  
    rate = (NUM_EVENTS / TIME_RANGE)

    #plotting-------------------
    #plot data  
    plt.hist(deltas, density=True, label="Observed distribution", bins=bins)
    plt.plot(bins, np.exp(-rate * bins) * rate)
    
    #plot labels and style
    plt.title('', fontsize = 15)
    plt.xlabel("Time between events", fontsize = 15)
    plt.ylabel("Fraction of events", fontsize = 15)
    
    # changing the fontsize of ticks
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    

NUM_EVENTS = 500
TIME_RANGE = 250
plot_new(NUM_EVENTS,TIME_RANGE)

# %% [markdown]
# <br>
#
# <a name='exercises_1_6'></a>
#
# | [Top](#section_1_0) | [Restart Section](#section_1_6) |

# %% [markdown]
# >#### Optional Problem 1.6.1 (ungraded)
# >
# >Why is the probability distribution of the time between independent events exponential?
# >
# >Hint 0: Consider, what is the probability of having 0 events within a time interval for a process that on average has N events per time interval?
# >
# >Hint 1: A different way to think about this is to imagine that you detect an event and start waiting for the next one. Some time has passed and you're still waiting. Has the probability distribution changed shape due to the fact that you waited or is it still the same?
# >
# >Hint 2: The probability distribution has not changed after you've waited some time $T$ (why?). That means that whatever the PDF $P(\Delta t)$ is, we must have $P(\Delta t) \propto P(\Delta t + T)$. The constant of proportionality is independent of $\Delta t$, and this formula is true for all $T$. Find a general class of distributions that satisfy this property. Then find the only distribution for which the mean value of $\Delta t$ is $1/r$.
